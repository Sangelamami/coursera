# %% [markdown]
# <H1> IBM Apply Data Science Capstone - Week 3 Segmenting and Clustering Neighborhoods in Toronto </H1>

# %% [markdown]
# <B> Import Libraries </B>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# <B> Load html table form Wikipedia - List of postal codes of Canada

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
result = requests.get(url)
html_file = result.content
 
soup = BeautifulSoup(html_file, "html.parser")

# %%
table = soup.find('table', class_='wikitable sortable')

# %%
table_rows = table.find_all('tr')

res = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    if row:
        res.append(row)

# %% [markdown]
# <B> Load data into dataframe </B>

# %%
df = pd.DataFrame(res, columns=["Postcode","Borough","Neighbourhood"])
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df.shape
# Out:
# (288, 3)

# %% [markdown]
# <B> Merge Neighbourhood with same Postcode and Borough </B>

# %%
Postcode = df.Postcode
Borough = df.Borough
Neighbourhood = df.Neighbourhood

unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []



for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 180

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.sort_values('Postcode')
df_toronto
# Out:
#     Postcode           Borough  \
# 0        M8A      Not assigned
# 1        M7V      Not assigned
# 2        M5A  Downtown Toronto
# 3        M9K      Not assigned
# 4        M5H  Downtown Toronto
# 5        M9V         Etobicoke
# 6        M8B      Not assigned
# 7        M7T      Not assigned
# 8        M5E  Downtown Toronto
# 9        M1A      Not assigned
# 10       M5W  Downtown Toronto
# 11       M1B       Scarborough
# 12       M4P   Central Toronto
# 13       M4R   Central Toronto
# 14       M2X      Not assigned
# 15       M5Y      Not assigned
# 16       M2S      Not assigned
# 17       M4H         East York
# 18       M6J      West Toronto
# 19       M7N      Not assigned
# 20       M1R       Scarborough
# 21       M2G      Not assigned
# 22       M1Y      Not assigned
# 23       M1M       Scarborough
# 24       M4Y  Downtown Toronto
# 25       M5N   Central Toronto
# 26       M7B      Not assigned
# 27       M7L      Not assigned
# 28       M5P   Central Toronto
# 29       M6X      Not assigned
# ..       ...               ...
# 150      M6T      Not assigned
# 151      M2E      Not assigned
# 152      M1J       Scarborough
# 153      M3B        North York
# 154      M7Y      East Toronto
# 155      M8H      Not assigned
# 156      M5Z      Not assigned
# 157      M2W      Not assigned
# 158      M6H      West Toronto
# 159      M8N      Not assigned
# 160      M3E      Not assigned
# 161      M8R      Not assigned
# 162      M5T  Downtown Toronto
# 163      M3K        North York
# 164      M3L        North York
# 165      M3A        North York
# 166      M1E       Scarborough
# 167      M4X  Downtown Toronto
# 168      M9Z      Not assigned
# 169      M3X      Not assigned
# 170      M9Y      Not assigned
# 171      M2V      Not assigned
# 172      M1P       Scarborough
# 173      M1G       Scarborough
# 174      M9S      Not assigned
# 175      M7C      Not assigned
# 176      M6Z      Not assigned
# 177      M4G         East York
# 178      M6L        North York
# 179      M4A        North York
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                            Harbourfront, Regent Park
# 3                                         Not assigned
# 4                             Adelaide, King, Richmond
# 5    Albion Gardens, Beaumond Heights, Humbergate, ...
# 6                                         Not assigned
# 7                                         Not assigned
# 8                                          Berczy Park
# 9                                         Not assigned
# 10                     Stn A PO Boxes 25 The Esplanade
# 11                                      Rouge, Malvern
# 12                                    Davisville North
# 13                                  North Toronto West
# 14                                        Not assigned
# 15                                        Not assigned
# 16                                        Not assigned
# 17                                    Thorncliffe Park
# 18                            Little Portugal, Trinity
# 19                                        Not assigned
# 20                                   Maryvale, Wexford
# 21                                        Not assigned
# 22                                        Not assigned
# 23     Cliffcrest, Cliffside, Scarborough Village West
# 24                                Church and Wellesley
# 25                                            Roselawn
# 26                                        Not assigned
# 27                                        Not assigned
# 28                 Forest Hill North, Forest Hill West
# 29                                        Not assigned
# ..                                                 ...
# 150                                       Not assigned
# 151                                       Not assigned
# 152                                Scarborough Village
# 153                                    Don Mills North
# 154  Business Reply Mail Processing Centre 969 Eastern
# 155                                       Not assigned
# 156                                       Not assigned
# 157                                       Not assigned
# 158                       Dovercourt Village, Dufferin
# 159                                       Not assigned
# 160                                       Not assigned
# 161                                       Not assigned
# 162          Chinatown, Grange Park, Kensington Market
# 163                        CFB Toronto, Downsview East
# 164                                     Downsview West
# 165                                          Parkwoods
# 166                  Guildwood, Morningside, West Hill
# 167                        Cabbagetown, St. James Town
# 168                                       Not assigned
# 169                                       Not assigned
# 170                                       Not assigned
# 171                                       Not assigned
# 172  Dorset Park, Scarborough Town Centre, Wexford ...
# 173                                             Woburn
# 174                                       Not assigned
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                            Leaside
# 178                 Downsview, North Park, Upwood Park
# 179                                   Victoria Village
#
# [180 rows x 3 columns]

# %%
df_toronto.shape
# Out:
# (180, 3)
