# %% [markdown]
# <H1> IBM Apply Data Science Capstone - Week 3 Segmenting and Clustering Neighborhoods in Toronto </H1>

# %% [markdown]
# <B> Import Libraries </B>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# <B> Load html table form Wikipedia - List of postal codes of Canada

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
result = requests.get(url)
html_file = result.content
 
soup = BeautifulSoup(html_file, "html.parser")

# %%
table = soup.find('table', class_='wikitable sortable')

# %%
table_rows = table.find_all('tr')

res = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    if row:
        res.append(row)

# %% [markdown]
# <B> Load data into dataframe </B>

# %%
df = pd.DataFrame(res, columns=["Postcode","Borough","Neighbourhood"])
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df.shape
# Out:
# (288, 3)

# %% [markdown]
# <B> Merge Neighbourhood with same Postcode and Borough </B>

# %%
Postcode = df.Postcode
Borough = df.Borough
Neighbourhood = df.Neighbourhood

unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []



for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 180

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.sort_values('Postcode')
df_toronto
# Out:
#     Postcode           Borough  \
# 0        M8X         Etobicoke
# 1        M9S      Not assigned
# 2        M2S      Not assigned
# 3        M2Z      Not assigned
# 4        M7B      Not assigned
# 5        M6W      Not assigned
# 6        M3Z      Not assigned
# 7        M4Z      Not assigned
# 8        M8H      Not assigned
# 9        M2T      Not assigned
# 10       M6X      Not assigned
# 11       M5J  Downtown Toronto
# 12       M4N   Central Toronto
# 13       M1Y      Not assigned
# 14       M7R       Mississauga
# 15       M7C      Not assigned
# 16       M4A        North York
# 17       M4X  Downtown Toronto
# 18       M4K      East Toronto
# 19       M1B       Scarborough
# 20       M5X  Downtown Toronto
# 21       M9E      Not assigned
# 22       M1G       Scarborough
# 23       M2J        North York
# 24       M2H        North York
# 25       M5B  Downtown Toronto
# 26       M1K       Scarborough
# 27       M3Y      Not assigned
# 28       M9A         Etobicoke
# 29       M6G  Downtown Toronto
# ..       ...               ...
# 150      M9H      Not assigned
# 151      M6A        North York
# 152      M8Z         Etobicoke
# 153      M1H       Scarborough
# 154      M2B      Not assigned
# 155      M4C         East York
# 156      M6P      West Toronto
# 157      M8V         Etobicoke
# 158      M5N   Central Toronto
# 159      M9G      Not assigned
# 160      M3K        North York
# 161      M5T  Downtown Toronto
# 162      M6M              York
# 163      M8A      Not assigned
# 164      M3W      Not assigned
# 165      M1W       Scarborough
# 166      M2G      Not assigned
# 167      M8C      Not assigned
# 168      M7Z      Not assigned
# 169      M5Z      Not assigned
# 170      M2V      Not assigned
# 171      M5P   Central Toronto
# 172      M9Y      Not assigned
# 173      M5A  Downtown Toronto
# 174      M8Y         Etobicoke
# 175      M3A        North York
# 176      M7V      Not assigned
# 177      M4L      East Toronto
# 178      M3M        North York
# 179      M6K      West Toronto
#
#                                          Neighbourhood
# 0        The Kingsway, Montgomery Road, Old Mill North
# 1                                         Not assigned
# 2                                         Not assigned
# 3                                         Not assigned
# 4                                         Not assigned
# 5                                         Not assigned
# 6                                         Not assigned
# 7                                         Not assigned
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                        Not assigned
# 11   Harbourfront East, Toronto Islands, Union Station
# 12                                       Lawrence Park
# 13                                        Not assigned
# 14               Canada Post Gateway Processing Centre
# 15                                        Not assigned
# 16                                    Victoria Village
# 17                         Cabbagetown, St. James Town
# 18                        The Danforth West, Riverdale
# 19                                      Rouge, Malvern
# 20              First Canadian Place, Underground city
# 21                                        Not assigned
# 22                                              Woburn
# 23                        Fairview, Henry Farm, Oriole
# 24                                   Hillcrest Village
# 25                            Ryerson, Garden District
# 26         East Birchmount Park, Ionview, Kennedy Park
# 27                                        Not assigned
# 28                                    Islington Avenue
# 29                                            Christie
# ..                                                 ...
# 150                                       Not assigned
# 151                   Lawrence Heights, Lawrence Manor
# 152  Kingsway Park South West, Mimico NW, The Queen...
# 153                                          Cedarbrae
# 154                                       Not assigned
# 155                                   Woodbine Heights
# 156                      High Park, The Junction South
# 157       Humber Bay Shores, Mimico South, New Toronto
# 158                                           Roselawn
# 159                                       Not assigned
# 160                        CFB Toronto, Downsview East
# 161          Chinatown, Grange Park, Kensington Market
# 162     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 163                                       Not assigned
# 164                                       Not assigned
# 165                                    L'Amoreaux West
# 166                                       Not assigned
# 167                                       Not assigned
# 168                                       Not assigned
# 169                                       Not assigned
# 170                                       Not assigned
# 171                Forest Hill North, Forest Hill West
# 172                                       Not assigned
# 173                          Harbourfront, Regent Park
# 174  Humber Bay, King's Mill Park, Kingsway Park So...
# 175                                          Parkwoods
# 176                                       Not assigned
# 177                     The Beaches West, India Bazaar
# 178                                  Downsview Central
# 179       Brockton, Exhibition Place, Parkdale Village
#
# [180 rows x 3 columns]

# %%
df_toronto.shape
# Out:
# (180, 3)

# %%
# read csv of 

df_geo = pd.read_csv("https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv") 

df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_geo.rename(columns = {"Postal Code":"Postcode"}, inplace=True)

df_geo.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
pd.merge(df_toronto, df_geo, on='Postcode', how='inner')
# Out:
#     Postcode           Borough  \
# 0        M8X         Etobicoke
# 1        M5J  Downtown Toronto
# 2        M4N   Central Toronto
# 3        M7R       Mississauga
# 4        M4A        North York
# 5        M4X  Downtown Toronto
# 6        M4K      East Toronto
# 7        M1B       Scarborough
# 8        M5X  Downtown Toronto
# 9        M1G       Scarborough
# 10       M2J        North York
# 11       M2H        North York
# 12       M5B  Downtown Toronto
# 13       M1K       Scarborough
# 14       M9A         Etobicoke
# 15       M6G  Downtown Toronto
# 16       M4Y  Downtown Toronto
# 17       M5W  Downtown Toronto
# 18       M3J        North York
# 19       M5E  Downtown Toronto
# 20       M9L        North York
# 21       M6B        North York
# 22       M1X       Scarborough
# 23       M3B        North York
# 24       M4J         East York
# 25       M6C              York
# 26       M9P         Etobicoke
# 27       M5G  Downtown Toronto
# 28       M9M        North York
# 29       M3C        North York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M1R       Scarborough
# 75       M6R      West Toronto
# 76       M5H  Downtown Toronto
# 77       M4G         East York
# 78       M4W  Downtown Toronto
# 79       M1T       Scarborough
# 80       M9N              York
# 81       M7Y      East Toronto
# 82       M5K  Downtown Toronto
# 83       M4B         East York
# 84       M4M      East Toronto
# 85       M6A        North York
# 86       M8Z         Etobicoke
# 87       M1H       Scarborough
# 88       M4C         East York
# 89       M6P      West Toronto
# 90       M8V         Etobicoke
# 91       M5N   Central Toronto
# 92       M3K        North York
# 93       M5T  Downtown Toronto
# 94       M6M              York
# 95       M1W       Scarborough
# 96       M5P   Central Toronto
# 97       M5A  Downtown Toronto
# 98       M8Y         Etobicoke
# 99       M3A        North York
# 100      M4L      East Toronto
# 101      M3M        North York
# 102      M6K      West Toronto
#
#                                          Neighbourhood   Latitude  Longitude
# 0        The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 1    Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 2                                        Lawrence Park  43.728020 -79.388790
# 3                Canada Post Gateway Processing Centre  43.636966 -79.615819
# 4                                     Victoria Village  43.725882 -79.315572
# 5                          Cabbagetown, St. James Town  43.667967 -79.367675
# 6                         The Danforth West, Riverdale  43.679557 -79.352188
# 7                                       Rouge, Malvern  43.806686 -79.194353
# 8               First Canadian Place, Underground city  43.648429 -79.382280
# 9                                               Woburn  43.770992 -79.216917
# 10                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 11                                   Hillcrest Village  43.803762 -79.363452
# 12                            Ryerson, Garden District  43.657162 -79.378937
# 13         East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 14                                    Islington Avenue  43.667856 -79.532242
# 15                                            Christie  43.669542 -79.422564
# 16                                Church and Wellesley  43.665860 -79.383160
# 17                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 18                     Northwood Park, York University  43.767980 -79.487262
# 19                                         Berczy Park  43.644771 -79.373306
# 20                                       Humber Summit  43.756303 -79.565963
# 21                                           Glencairn  43.709577 -79.445073
# 22                                         Upper Rouge  43.836125 -79.205636
# 23                                     Don Mills North  43.745906 -79.352188
# 24                                        East Toronto  43.685347 -79.338106
# 25                                  Humewood-Cedarvale  43.693781 -79.428191
# 26                                           Westmount  43.696319 -79.532242
# 27                                  Central Bay Street  43.657952 -79.387383
# 28                                    Emery, Humberlea  43.724766 -79.532242
# 29                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                                   Maryvale, Wexford  43.750072 -79.295849
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76                            Adelaide, King, Richmond  43.650571 -79.384568
# 77                                             Leaside  43.709060 -79.363452
# 78                                            Rosedale  43.679563 -79.377529
# 79             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 80                                              Weston  43.706876 -79.518188
# 81   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 82            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 83                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 84                                     Studio District  43.659526 -79.340923
# 85                    Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 86   Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
# 87                                           Cedarbrae  43.773136 -79.239476
# 88                                    Woodbine Heights  43.695344 -79.318389
# 89                       High Park, The Junction South  43.661608 -79.464763
# 90        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 91                                            Roselawn  43.711695 -79.416936
# 92                         CFB Toronto, Downsview East  43.737473 -79.464763
# 93           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 94      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 95                                     L'Amoreaux West  43.799525 -79.318389
# 96                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 97                           Harbourfront, Regent Park  43.654260 -79.360636
# 98   Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 99                                           Parkwoods  43.753259 -79.329656
# 100                     The Beaches West, India Bazaar  43.668999 -79.315572
# 101                                  Downsview Central  43.728496 -79.495697
# 102       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
#
# [103 rows x 5 columns]
