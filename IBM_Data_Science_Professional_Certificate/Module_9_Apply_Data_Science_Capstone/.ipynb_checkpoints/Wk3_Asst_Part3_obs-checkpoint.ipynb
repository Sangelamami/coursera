# %% [markdown]
# <H1> IBM Apply Data Science Capstone - Week 3 Segmenting and Clustering Neighborhoods in Toronto </H1>

# %% [markdown]
# <B> Import Libraries </B>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
#!conda install -c conda-forge folium
#import folium # map rendering library

print("Library import completed")
# Out:
# Library import completed

# %%
import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
import folium # map rendering library

print ("folium imported")
# Out:
# folium imported

# %% [markdown]
# <B> Load html table form Wikipedia - List of postal codes of Canada

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
result = requests.get(url)
html_file = result.content
 
soup = BeautifulSoup(html_file, "html.parser")

# %%
table = soup.find('table', class_='wikitable sortable')

# %%
table_rows = table.find_all('tr')

res = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    if row:
        res.append(row)

# %% [markdown]
# <B> Load data into dataframe </B>

# %%
df = pd.DataFrame(res, columns=["Postcode","Borough","Neighbourhood"])
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df.shape
# Out:
# (288, 3)

# %% [markdown]
# <B> Merge Neighbourhood with same Postcode and Borough </B>

# %%
Postcode = df.Postcode
Borough = df.Borough
Neighbourhood = df.Neighbourhood

unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []



for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 180

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.sort_values('Postcode')
df_toronto
# Out:
#     Postcode           Borough  \
# 0        M5T  Downtown Toronto
# 1        M9H      Not assigned
# 2        M1Z      Not assigned
# 3        M2H        North York
# 4        M6M              York
# 5        M1G       Scarborough
# 6        M5X  Downtown Toronto
# 7        M7Z      Not assigned
# 8        M9A         Etobicoke
# 9        M7L      Not assigned
# 10       M3N        North York
# 11       M4L      East Toronto
# 12       M9R         Etobicoke
# 13       M4J         East York
# 14       M3T      Not assigned
# 15       M1E       Scarborough
# 16       M9J      Not assigned
# 17       M5W  Downtown Toronto
# 18       M2X      Not assigned
# 19       M2J        North York
# 20       M9C         Etobicoke
# 21       M7M      Not assigned
# 22       M3J        North York
# 23       M5K  Downtown Toronto
# 24       M4X  Downtown Toronto
# 25       M3R      Not assigned
# 26       M2M        North York
# 27       M6T      Not assigned
# 28       M1R       Scarborough
# 29       M4M      East Toronto
# ..       ...               ...
# 150      M4G         East York
# 151      M7G      Not assigned
# 152      M7E      Not assigned
# 153      M2T      Not assigned
# 154      M9S      Not assigned
# 155      M7Y      East Toronto
# 156      M6J      West Toronto
# 157      M1B       Scarborough
# 158      M9B         Etobicoke
# 159      M7H      Not assigned
# 160      M6Z      Not assigned
# 161      M1K       Scarborough
# 162      M2Y      Not assigned
# 163      M1A      Not assigned
# 164      M7T      Not assigned
# 165      M3L        North York
# 166      M5M        North York
# 167      M9X      Not assigned
# 168      M5R   Central Toronto
# 169      M3P      Not assigned
# 170      M6C              York
# 171      M1C       Scarborough
# 172      M3K        North York
# 173      M6P      West Toronto
# 174      M2L        North York
# 175      M7J      Not assigned
# 176      M7S      Not assigned
# 177      M8S      Not assigned
# 178      M1S       Scarborough
# 179      M8P      Not assigned
#
#                                          Neighbourhood
# 0            Chinatown, Grange Park, Kensington Market
# 1                                         Not assigned
# 2                                         Not assigned
# 3                                    Hillcrest Village
# 4       Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 5                                               Woburn
# 6               First Canadian Place, Underground city
# 7                                         Not assigned
# 8                                     Islington Avenue
# 9                                         Not assigned
# 10                                 Downsview Northwest
# 11                      The Beaches West, India Bazaar
# 12   Kingsview Village, Martin Grove Gardens, Richv...
# 13                                        East Toronto
# 14                                        Not assigned
# 15                   Guildwood, Morningside, West Hill
# 16                                        Not assigned
# 17                     Stn A PO Boxes 25 The Esplanade
# 18                                        Not assigned
# 19                        Fairview, Henry Farm, Oriole
# 20   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 21                                        Not assigned
# 22                     Northwood Park, York University
# 23            Design Exchange, Toronto Dominion Centre
# 24                         Cabbagetown, St. James Town
# 25                                        Not assigned
# 26                             Newtonbrook, Willowdale
# 27                                        Not assigned
# 28                                   Maryvale, Wexford
# 29                                     Studio District
# ..                                                 ...
# 150                                            Leaside
# 151                                       Not assigned
# 152                                       Not assigned
# 153                                       Not assigned
# 154                                       Not assigned
# 155  Business Reply Mail Processing Centre 969 Eastern
# 156                           Little Portugal, Trinity
# 157                                     Rouge, Malvern
# 158  Cloverdale, Islington, Martin Grove, Princess ...
# 159                                       Not assigned
# 160                                       Not assigned
# 161        East Birchmount Park, Ionview, Kennedy Park
# 162                                       Not assigned
# 163                                       Not assigned
# 164                                       Not assigned
# 165                                     Downsview West
# 166                  Bedford Park, Lawrence Manor East
# 167                                       Not assigned
# 168                The Annex, North Midtown, Yorkville
# 169                                       Not assigned
# 170                                 Humewood-Cedarvale
# 171             Highland Creek, Rouge Hill, Port Union
# 172                        CFB Toronto, Downsview East
# 173                      High Park, The Junction South
# 174                           Silver Hills, York Mills
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178                                          Agincourt
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %%
df_toronto.shape
# Out:
# (180, 3)

# %%
# read csv of 

df_geo = pd.read_csv("https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv") 

df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_geo.rename(columns = {"Postal Code":"Postcode"}, inplace=True)

df_geo.head()
# Out:
#   Postcode           Borough                                   Neighbourhood  \
# 0      M5T  Downtown Toronto       Chinatown, Grange Park, Kensington Market
# 1      M2H        North York                               Hillcrest Village
# 2      M6M              York  Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 3      M1G       Scarborough                                          Woburn
# 4      M5X  Downtown Toronto          First Canadian Place, Underground city
#
#     Latitude  Longitude
# 0  43.653206 -79.400049
# 1  43.803762 -79.363452
# 2  43.691116 -79.476013
# 3  43.770992 -79.216917
# 4  43.648429 -79.382280

# %%
df_geo2=pd.merge(df_toronto, df_geo, on='Postcode', how='inner')

# %%
df_geo3 = df_geo2.drop(['Borough_x', 'Borough_y', 'Neighbourhood_x','Neighbourhood_y'], axis =1)

# %%
df_geo3.head()
# Out:
#   Postcode           Borough                                   Neighbourhood  \
# 0      M5T  Downtown Toronto       Chinatown, Grange Park, Kensington Market
# 1      M2H        North York                               Hillcrest Village
# 2      M6M              York  Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 3      M1G       Scarborough                                          Woburn
# 4      M5X  Downtown Toronto          First Canadian Place, Underground city
#
#     Latitude  Longitude
# 0  43.653206 -79.400049
# 1  43.803762 -79.363452
# 2  43.691116 -79.476013
# 3  43.770992 -79.216917
# 4  43.648429 -79.382280

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_geo3['Latitude'], df_geo3['Longitude'], df_geo3['Borough'], df_geo3['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_data = df_geo3[df_geo3['Borough'].str.contains("Toronto")].reset_index(drop=True)
print(toronto_data.shape)
toronto_data.head()
# Out:
# (38, 5)
#   Postcode           Borough                              Neighbourhood  \
# 0      M5T  Downtown Toronto  Chinatown, Grange Park, Kensington Market
# 1      M5X  Downtown Toronto     First Canadian Place, Underground city
# 2      M4L      East Toronto             The Beaches West, India Bazaar
# 3      M5W  Downtown Toronto            Stn A PO Boxes 25 The Esplanade
# 4      M5K  Downtown Toronto   Design Exchange, Toronto Dominion Centre
#
#     Latitude  Longitude
# 0  43.653206 -79.400049
# 1  43.648429 -79.382280
# 2  43.668999 -79.315572
# 3  43.646435 -79.374846
# 4  43.647177 -79.381576

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'T1SHYGRI3N4I0XNYW15EXEA0E1E5QOESRY0DJGCNRF2KIL32' # your Foursquare ID
CLIENT_SECRET = 'FUJZSSXA34HOWKVD50VBPNHHY0GH5MPIFE5FJZRACHPYJLXY' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: T1SHYGRI3N4I0XNYW15EXEA0E1E5QOESRY0DJGCNRF2KIL32
# CLIENT_SECRET:FUJZSSXA34HOWKVD50VBPNHHY0GH5MPIFE5FJZRACHPYJLXY

# %%
toronto_data.loc[0, 'Neighborhood']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [Neighborhood] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-fccabaac0b75> in <module>()
# ----> 1 toronto_data.loc[0, 'Neighborhood']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1025                     return section
#    1026                 # This is an elided recursive call to iloc/loc/etc'
# -> 1027                 return getattr(section, self.name)[new_key]
#    1028
#    1029         raise IndexingError('not applicable')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [Neighborhood] is not in the [index]'

# %%
neighborhood_latitude = toronto_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = toronto_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = toronto_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-d6e5adca6230> in <module>()
#       7     CLIENT_SECRET,
#       8     VERSION,
# ----> 9     neighborhood_latitude,
#      10     neighborhood_longitude,
#      11     radius,
#
# NameError: name 'neighborhood_latitude' is not defined
